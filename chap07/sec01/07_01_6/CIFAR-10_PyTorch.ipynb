# %%
'''
1. データの読み込みと前処理
'''
import os
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# ダウンロード先のディレクトリ
root = './data'

# トランスフォーマーオブジェクトを生成
transform_train = transforms.Compose(
    [transforms.ToTensor(), # Tensorオブジェクトに変換
     transforms.Normalize((0.5), (0.5)) # 平均0.5、標準偏差0.5で正規化
     ])

transform_val = transforms.Compose(
     [transforms.ToTensor(), # Tensorオブジェクトに変換
     transforms.Normalize((0.5), (0.5)) # 平均0.5、標準偏差0.5で正規化
     ])

# 訓練用データの読み込み
f_mnist_train = datasets.CIFAR10(
    root=root,     # データの保存先のディレクトリ
    download=True, # ダウンロードを許可
    train=True,    # 訓練データを指定
    transform=transform_train) # トランスフォーマーオブジェクトを指定

# テスト用データの読み込み
f_mnist_test = datasets.CIFAR10(
    root=root,     # データの保存先のディレクトリ
    download=True, # ダウンロードを許可
    train=False,   # テストデータを指定
    transform=transform_val) # トランスフォーマーオブジェクトを指定

# ミニバッチのサイズ
batch_size = 64
# 訓練用のデータローダー
train_dataloader = DataLoader(f_mnist_train, # 訓練データ
                              batch_size=batch_size, # ミニバッチのサイズ
                              shuffle=True) # シャッフルして抽出
# テスト用のデータローダー
test_dataloader = DataLoader(f_mnist_test, # テストデータ
                             batch_size=batch_size, # ミニバッチのサイズ
                             shuffle=False) # シャッフルして抽出

# データローダーが返すミニバッチの先頭データの形状を出力
for (x, t) in train_dataloader: # 訓練データ
    print(x.shape)
    print(t.shape)
    break

for (x, t) in test_dataloader: # テストデータ
    print(x.shape)
    print(t.shape)
    break
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([64, 3, 32, 32])
# torch.Size([64])
# torch.Size([64, 3, 32, 32])
# torch.Size([64])

# %%
'''
2. モデルの定義
'''
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    '''畳み込みニューラルネットワーク
    
    Attributes:
      conv1(Conv2d): 畳み込み層
      conv2(Conv2d): 畳み込み層
      pool1(MaxPool2d): プーリング層
      dropput1(Dropout2d): ドロップアウト
      conv2D_3(Conv2d): 畳み込み層
      conv2D_4(Conv2d): 畳み込み層
      pool2(MaxPool2d): プーリング層
      dropput2(Dropout2d): ドロップアウト
      fc1(Linear): 全結合層
      dropput3(Dropout): ドロップアウト
      fc2(Linear): 全結合層
    '''
    def __init__(self):
        '''モデルの初期化を行う          
        '''
        # スーパークラスの__init__()を実行
        super().__init__()

        # 第1層: 畳み込み層1
        # (バッチサイズ,3,32,32) -> (バッチサイズ,32,32,32)
        self.conv1 = nn.Conv2d(in_channels=3,   # 入力チャネル数
                               out_channels=32, # 出力チャネル数
                               kernel_size=3,   # フィルターサイズ
                               padding=True,    # パディングを行う
                               padding_mode='zeros')

        # 第2層: 畳み込み層2
        # (バッチサイズ,32,32,32) ->(バッチサイズ,32,32,32)
        self.conv2 = nn.Conv2d(in_channels=32,  # 入力チャネル数
                               out_channels=32, # 出力チャネル数
                               kernel_size=3,   # フィルターサイズ
                               padding=True,    # パディングを行う
                               padding_mode='zeros')
       
        # 第3層: プーリング層1
        # (バッチサイズ,32,32,32) -> (バッチサイズ,32,16,16)
        self.pool1 = nn.MaxPool2d(2, 2)
        # ドロップアウト1: 50%
        self.dropout1 = nn.Dropout2d(0.5)

        # 第4層: 畳み込み層3
        # (バッチサイズ,32,16,16) ->(バッチサイズ,64,16,16)
        self.conv3 = nn.Conv2d(in_channels=32,  # 入力チャネル数
                               out_channels=64, # 出力チャネル数
                               kernel_size=3,   # フィルターサイズ
                               padding=True,    # パディングを行う
                               padding_mode='zeros')

        # 第5層: 畳み込み層4
        # (バッチサイズ,64,16,16) ->(バッチサイズ,64,16,16)
        self.conv4 = nn.Conv2d(in_channels=64,  # 入力チャネル数
                               out_channels=64, # 出力チャネル数
                               kernel_size=3,   # フィルターサイズ
                               padding=True,    # パディングを行う
                               padding_mode='zeros')

        # 第6層: プーリング層2
        # (バッチサイズ,64,16,16) ->(バッチサイズ,64,8,8)
        self.pool2 = nn.MaxPool2d(2, 2)
        # ドロップアウト2: 50%
        self.dropout2 = nn.Dropout2d(0.5)

        # 第10層: 全結合層1
        # (バッチサイズ,4096) -> (バッチサイズ,512)
        self.fc1 = nn.Linear(64*8*8, 512)
        # ドロップアウト3: 50%
        self.dropout3 = nn.Dropout(0.5)

        # 第11層: 出力層
        # (バッチサイズ,512) -> (バッチサイズ,10)
        self.fc2 = nn.Linear(512, 10)
        
    def forward(self, x):
        '''MLPの順伝播処理を行う
        
        Parameters:
          x(ndarray(float32)):訓練データ、または検証データ
          
        Returns(float32):
          出力層からの出力値    
        '''
        x = F.relu(self.conv1(x))             # conv1
        x = self.pool1(F.relu(self.conv2(x))) # conv2 ->pool1
        x = self.dropout1(x)
        x = F.relu(self.conv3(x))             # conv3
        x = self.pool2( F.relu(self.conv4(x))) # conv4 ->pool2
        x = self.dropout2(x)
        x = x.view(-1, 64*8*8)                # フラット化
        x = F.relu(self.fc1(x))               # fc1
        x = self.dropout3(x)
        x = self.fc2(x)                       # fc2
        return x

# %%
'''
3. モデルの生成
'''
import torch

# 使用可能なデバイス(CPUまたはGPU）を取得する
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# モデルオブジェクトを生成し、使用可能なデバイスを設定する
model = CNN().to(device)

model # モデルの構造を出力
# Out:
# CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(True, True))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(True, True))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.5, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(True, True))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(True, True))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=4096, out_features=512, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
'''
4. 損失関数とオプティマイザーの生成
'''
import torch.optim

# クロスエントロピー誤差のオブジェクトを生成
criterion = nn.CrossEntropyLoss()
# 勾配降下アルゴリズムを使用するオプティマイザーを生成
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
'''
5. 勾配降下アルゴリズムによるパラメーターの更新処理
'''
def train_step(x, t):
    '''バックプロパゲーションによるパラメーター更新を行う
    
    Parameters: x: 訓練データ
                t: 正解ラベル                
    Returns:
      MLPの出力と正解ラベルのクロスエントロピー誤差
    '''
    model.train()    # モデルを訓練(学習)モードにする
    preds = model(x) # モデルの出力を取得
    loss = criterion(preds, t) # 出力と正解ラベルの誤差から損失を取得
    optimizer.zero_grad() # 勾配を0で初期化（累積してしまうため）
    loss.backward()  # 逆伝播の処理(自動微分による勾配計算)
    optimizer.step() # 勾配降下法の更新式を適用してバイアス、重みを更新

    return loss, preds

# %%
'''
6. モデルの評価を行う関数
'''
def test_step(x, t):
    '''テストデータを入力して損失と予測値を返す
    
    Parameters: x: テストデータ
                t: 正解ラベル
    Returns:
      MLPの出力と正解ラベルのクロスエントロピー誤差
    '''
    model.eval()     # モデルを評価モードにする
    preds = model(x) # モデルの出力を取得
    loss = criterion(preds, t) # 出力と正解ラベルの誤差から損失を取得

    return loss, preds

# %%
# %%time
'''
7.モデルを使用して学習する
'''
from sklearn.metrics import accuracy_score

# エポック数
epochs = 120
# 損失と精度の履歴を保存するためのdictオブジェクト
history = {'loss':[],'accuracy':[], 'test_loss':[], 'test_accuracy':[]}

# 収束が停滞したら学習率を減衰するスケジューラー
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,   # オプティマイザーを指定
    mode='max',  # 監視対象は最大値
    factor=0.5,  # 学習率を減衰する割合
    patience=10, # 監視対象のエポック数
    min_lr=0.0001, # 最小学習率
    verbose=True # 学習率を減衰した場合に通知する
    )

# 学習を行う
for epoch in range(epochs):
    train_loss = 0. # 訓練1エポックあたりの損失を保持する変数
    train_acc = 0.  # 訓練1エポックごとの精度を保持する変数
    test_loss = 0.  # 評価1エポックごとの損失を保持する変数
    test_acc = 0.   # 評価1エポックごとの精度を保持する変数

    # 1ステップにおける訓練用ミニバッチを使用した学習
    for (x, t) in train_dataloader:
        # torch.Tensorオブジェクトにデバイスを割り当てる
        x, t = x.to(device), t.to(device)
        loss, preds = train_step(x, t) # 損失と予測値を取得
        train_loss += loss.item()      # ステップごとの損失を加算
        train_acc += accuracy_score(
            t.tolist(),
            preds.argmax(dim=-1).tolist()
        )                              # ステップごとの精度を加算

    # 1ステップにおけるテストデータのミニバッチを使用した評価
    for (x, t) in test_dataloader:
        # torch.Tensorオブジェクトにデバイスを割り当てる
        x, t = x.to(device), t.to(device)
        loss, preds = test_step(x, t) # 損失と予測値を取得
        test_loss += loss.item()       # ステップごとの損失を加算
        test_acc += accuracy_score(
            t.tolist(),
            preds.argmax(dim=-1).tolist()
        )                              # ステップごとの精度を加算

    # 訓練時の損失の平均値を取得
    avg_train_loss = train_loss / len(train_dataloader)
    # 訓練時の精度の平均値を取得
    avg_train_acc = train_acc / len(train_dataloader)
    # 検証時の損失の平均値を取得
    avg_test_loss = test_loss / len(test_dataloader)
    # 検証時の精度の平均値を取得
    avg_test_acc = test_acc / len(test_dataloader)

    # 訓練データの履歴を保存する
    history['loss'].append(avg_train_loss)
    history['accuracy'].append(avg_train_acc)
    # テストデータの履歴を保存する
    history['test_loss'].append(avg_test_loss)
    history['test_accuracy'].append(avg_test_acc)

    # 1エポックごとに結果を出力
    if (epoch + 1) % 1 == 0:
        print(
            'epoch({}) train_loss: {:.4} train_acc: {:.4} val_loss: {:.4} val_acc: {:.4}'.format(
                epoch+1,
                avg_train_loss, # 訓練データの損失を出力
                avg_train_acc,  # 訓練データの精度を出力
                avg_test_loss,  # テストデータの損失を出力
                avg_test_acc    # テストデータの精度を出力
    ))
    # スケジューラー、テストデータの精度を監視する
    scheduler.step(avg_test_acc)
# Out:
# epoch(1) train_loss: 1.75 train_acc: 0.3632 val_loss: 1.377 val_acc: 0.5038
# epoch(2) train_loss: 1.431 train_acc: 0.4846 val_loss: 1.212 val_acc: 0.5738
# epoch(3) train_loss: 1.307 train_acc: 0.5303 val_loss: 1.09 val_acc: 0.6259
# epoch(4) train_loss: 1.209 train_acc: 0.5661 val_loss: 1.023 val_acc: 0.6407
# epoch(5) train_loss: 1.161 train_acc: 0.5861 val_loss: 0.9753 val_acc: 0.6669
# epoch(6) train_loss: 1.114 train_acc: 0.6035 val_loss: 0.9637 val_acc: 0.6678
# epoch(7) train_loss: 1.076 train_acc: 0.6188 val_loss: 0.9111 val_acc: 0.6805
# epoch(8) train_loss: 1.039 train_acc: 0.6313 val_loss: 0.8947 val_acc: 0.6969
# epoch(9) train_loss: 1.02 train_acc: 0.6424 val_loss: 0.8992 val_acc: 0.6896
# epoch(10) train_loss: 0.9981 train_acc: 0.6463 val_loss: 0.8486 val_acc: 0.7068
# epoch(11) train_loss: 0.9687 train_acc: 0.657 val_loss: 0.8594 val_acc: 0.7029
# epoch(12) train_loss: 0.9526 train_acc: 0.6632 val_loss: 0.8448 val_acc: 0.7139
# epoch(13) train_loss: 0.9412 train_acc: 0.6704 val_loss: 0.8157 val_acc: 0.7227
# epoch(14) train_loss: 0.9195 train_acc: 0.675 val_loss: 0.8249 val_acc: 0.7147
# epoch(15) train_loss: 0.9047 train_acc: 0.6813 val_loss: 0.8309 val_acc: 0.7128
# epoch(16) train_loss: 0.8966 train_acc: 0.6847 val_loss: 0.8074 val_acc: 0.7194
# epoch(17) train_loss: 0.881 train_acc: 0.6899 val_loss: 0.7881 val_acc: 0.7301
# epoch(18) train_loss: 0.8698 train_acc: 0.6944 val_loss: 0.8153 val_acc: 0.7148
# epoch(19) train_loss: 0.8579 train_acc: 0.6985 val_loss: 0.7903 val_acc: 0.7261
# epoch(20) train_loss: 0.8502 train_acc: 0.7002 val_loss: 0.7972 val_acc: 0.7232
# epoch(21) train_loss: 0.8392 train_acc: 0.7059 val_loss: 0.7877 val_acc: 0.7287
# epoch(22) train_loss: 0.8248 train_acc: 0.7102 val_loss: 0.7942 val_acc: 0.723
# epoch(23) train_loss: 0.8182 train_acc: 0.7125 val_loss: 0.7796 val_acc: 0.7315
# epoch(24) train_loss: 0.813 train_acc: 0.7108 val_loss: 0.7843 val_acc: 0.7261
# epoch(25) train_loss: 0.7953 train_acc: 0.7198 val_loss: 0.7745 val_acc: 0.7315
# epoch(26) train_loss: 0.7905 train_acc: 0.7229 val_loss: 0.7736 val_acc: 0.7386
# epoch(27) train_loss: 0.7887 train_acc: 0.7215 val_loss: 0.759 val_acc: 0.7352
# epoch(28) train_loss: 0.7761 train_acc: 0.7269 val_loss: 0.7641 val_acc: 0.7335
# epoch(29) train_loss: 0.7803 train_acc: 0.7285 val_loss: 0.7493 val_acc: 0.7441
# epoch(30) train_loss: 0.7628 train_acc: 0.7291 val_loss: 0.7488 val_acc: 0.7392
# epoch(31) train_loss: 0.7621 train_acc: 0.7315 val_loss: 0.7606 val_acc: 0.7352
# epoch(32) train_loss: 0.7543 train_acc: 0.735 val_loss: 0.7453 val_acc: 0.7461
# epoch(33) train_loss: 0.7448 train_acc: 0.7384 val_loss: 0.7396 val_acc: 0.7419
# epoch(34) train_loss: 0.7468 train_acc: 0.7381 val_loss: 0.7475 val_acc: 0.74
# epoch(35) train_loss: 0.7309 train_acc: 0.7432 val_loss: 0.7386 val_acc: 0.7414
# epoch(36) train_loss: 0.7311 train_acc: 0.7417 val_loss: 0.7413 val_acc: 0.7434
# epoch(37) train_loss: 0.7301 train_acc: 0.7454 val_loss: 0.7433 val_acc: 0.7429
# epoch(38) train_loss: 0.7252 train_acc: 0.7455 val_loss: 0.7466 val_acc: 0.7425
# epoch(39) train_loss: 0.7158 train_acc: 0.7507 val_loss: 0.7167 val_acc: 0.7495
# epoch(40) train_loss: 0.7173 train_acc: 0.7475 val_loss: 0.7378 val_acc: 0.7451
# epoch(41) train_loss: 0.7102 train_acc: 0.7497 val_loss: 0.72 val_acc: 0.748
# epoch(42) train_loss: 0.7078 train_acc: 0.7516 val_loss: 0.7371 val_acc: 0.7457
# epoch(43) train_loss: 0.699 train_acc: 0.7567 val_loss: 0.7264 val_acc: 0.7493
# epoch(44) train_loss: 0.691 train_acc: 0.7565 val_loss: 0.7325 val_acc: 0.7456
# epoch(45) train_loss: 0.6917 train_acc: 0.7575 val_loss: 0.7402 val_acc: 0.742
# epoch(46) train_loss: 0.6905 train_acc: 0.7579 val_loss: 0.7446 val_acc: 0.7362
# epoch(47) train_loss: 0.6816 train_acc: 0.7628 val_loss: 0.7412 val_acc: 0.7416
# epoch(48) train_loss: 0.6772 train_acc: 0.7614 val_loss: 0.7273 val_acc: 0.7462
# epoch(49) train_loss: 0.671 train_acc: 0.761 val_loss: 0.7261 val_acc: 0.7514
# epoch(50) train_loss: 0.6699 train_acc: 0.7642 val_loss: 0.7269 val_acc: 0.7446
# epoch(51) train_loss: 0.6637 train_acc: 0.7668 val_loss: 0.7425 val_acc: 0.7375
# epoch(52) train_loss: 0.6573 train_acc: 0.7706 val_loss: 0.7351 val_acc: 0.7461
# epoch(53) train_loss: 0.6553 train_acc: 0.7719 val_loss: 0.7546 val_acc: 0.7377
# epoch(54) train_loss: 0.657 train_acc: 0.7694 val_loss: 0.7125 val_acc: 0.7542
# epoch(55) train_loss: 0.6538 train_acc: 0.7715 val_loss: 0.7631 val_acc: 0.7334
# epoch(56) train_loss: 0.6545 train_acc: 0.7707 val_loss: 0.7763 val_acc: 0.7276
# epoch(57) train_loss: 0.647 train_acc: 0.774 val_loss: 0.7177 val_acc: 0.7508
# epoch(58) train_loss: 0.643 train_acc: 0.775 val_loss: 0.7326 val_acc: 0.7509
# epoch(59) train_loss: 0.6383 train_acc: 0.7764 val_loss: 0.7226 val_acc: 0.753
# epoch(60) train_loss: 0.636 train_acc: 0.7779 val_loss: 0.7369 val_acc: 0.7397
# epoch(61) train_loss: 0.6315 train_acc: 0.779 val_loss: 0.734 val_acc: 0.7493
# epoch(62) train_loss: 0.6278 train_acc: 0.7802 val_loss: 0.7532 val_acc: 0.7357
# epoch(63) train_loss: 0.6206 train_acc: 0.7827 val_loss: 0.7175 val_acc: 0.749
# epoch(64) train_loss: 0.6237 train_acc: 0.7818 val_loss: 0.722 val_acc: 0.7502
# epoch(65) train_loss: 0.6206 train_acc: 0.7847 val_loss: 0.721 val_acc: 0.7489
# Epoch    65: reducing learning rate of group 0 to 5.0000e-04.
# epoch(66) train_loss: 0.5735 train_acc: 0.8013 val_loss: 0.6998 val_acc: 0.7598
# epoch(67) train_loss: 0.5523 train_acc: 0.8067 val_loss: 0.6972 val_acc: 0.7613
# epoch(68) train_loss: 0.5431 train_acc: 0.8072 val_loss: 0.6954 val_acc: 0.7614
# epoch(69) train_loss: 0.5292 train_acc: 0.8142 val_loss: 0.6964 val_acc: 0.7618
# epoch(70) train_loss: 0.5222 train_acc: 0.8168 val_loss: 0.6906 val_acc: 0.7617
# epoch(71) train_loss: 0.5203 train_acc: 0.8179 val_loss: 0.6964 val_acc: 0.7623
# epoch(72) train_loss: 0.5159 train_acc: 0.8178 val_loss: 0.6863 val_acc: 0.7642
# epoch(73) train_loss: 0.5078 train_acc: 0.8212 val_loss: 0.7156 val_acc: 0.7516
# epoch(74) train_loss: 0.5091 train_acc: 0.821 val_loss: 0.7022 val_acc: 0.7621
# epoch(75) train_loss: 0.5044 train_acc: 0.8225 val_loss: 0.7061 val_acc: 0.7571
# epoch(76) train_loss: 0.5032 train_acc: 0.8233 val_loss: 0.6922 val_acc: 0.7636
# epoch(77) train_loss: 0.5 train_acc: 0.8249 val_loss: 0.7024 val_acc: 0.7636
# epoch(78) train_loss: 0.4918 train_acc: 0.8268 val_loss: 0.7017 val_acc: 0.7609
# epoch(79) train_loss: 0.4896 train_acc: 0.8276 val_loss: 0.6981 val_acc: 0.7624
# epoch(80) train_loss: 0.4897 train_acc: 0.826 val_loss: 0.6932 val_acc: 0.7641
# epoch(81) train_loss: 0.486 train_acc: 0.8276 val_loss: 0.7073 val_acc: 0.7568
# epoch(82) train_loss: 0.4806 train_acc: 0.8317 val_loss: 0.7022 val_acc: 0.7628
# epoch(83) train_loss: 0.4743 train_acc: 0.8338 val_loss: 0.6994 val_acc: 0.7661
# epoch(84) train_loss: 0.4762 train_acc: 0.8329 val_loss: 0.6929 val_acc: 0.7651
# epoch(85) train_loss: 0.4787 train_acc: 0.8309 val_loss: 0.704 val_acc: 0.7599
# epoch(86) train_loss: 0.4782 train_acc: 0.8315 val_loss: 0.7036 val_acc: 0.7601
# epoch(87) train_loss: 0.4657 train_acc: 0.8371 val_loss: 0.7045 val_acc: 0.763
# epoch(88) train_loss: 0.4702 train_acc: 0.8333 val_loss: 0.7016 val_acc: 0.7602
# epoch(89) train_loss: 0.4697 train_acc: 0.8362 val_loss: 0.704 val_acc: 0.7637
# epoch(90) train_loss: 0.4662 train_acc: 0.8367 val_loss: 0.6988 val_acc: 0.7673
# epoch(91) train_loss: 0.461 train_acc: 0.8378 val_loss: 0.6914 val_acc: 0.7679
# epoch(92) train_loss: 0.4561 train_acc: 0.8397 val_loss: 0.7054 val_acc: 0.762
# epoch(93) train_loss: 0.465 train_acc: 0.8373 val_loss: 0.7057 val_acc: 0.7607
# epoch(94) train_loss: 0.4589 train_acc: 0.8358 val_loss: 0.7137 val_acc: 0.7607
# epoch(95) train_loss: 0.4525 train_acc: 0.8426 val_loss: 0.7057 val_acc: 0.7614
# epoch(96) train_loss: 0.4476 train_acc: 0.8435 val_loss: 0.7 val_acc: 0.7666
# epoch(97) train_loss: 0.4489 train_acc: 0.8427 val_loss: 0.7102 val_acc: 0.7602
# epoch(98) train_loss: 0.4487 train_acc: 0.8413 val_loss: 0.7016 val_acc: 0.7625
# epoch(99) train_loss: 0.4407 train_acc: 0.8449 val_loss: 0.7202 val_acc: 0.7572
# epoch(100) train_loss: 0.45 train_acc: 0.8423 val_loss: 0.7041 val_acc: 0.7624
# epoch(101) train_loss: 0.436 train_acc: 0.8463 val_loss: 0.7032 val_acc: 0.7622
# epoch(102) train_loss: 0.4468 train_acc: 0.8451 val_loss: 0.72 val_acc: 0.7591
# Epoch   102: reducing learning rate of group 0 to 2.5000e-04.
# epoch(103) train_loss: 0.4162 train_acc: 0.8529 val_loss: 0.7041 val_acc: 0.7647
# epoch(104) train_loss: 0.4037 train_acc: 0.8583 val_loss: 0.6996 val_acc: 0.7674
# epoch(105) train_loss: 0.403 train_acc: 0.8563 val_loss: 0.6896 val_acc: 0.7686
# epoch(106) train_loss: 0.4057 train_acc: 0.8558 val_loss: 0.6986 val_acc: 0.7648
# epoch(107) train_loss: 0.402 train_acc: 0.8591 val_loss: 0.6936 val_acc: 0.7676
# epoch(108) train_loss: 0.3945 train_acc: 0.8613 val_loss: 0.7022 val_acc: 0.7685
# epoch(109) train_loss: 0.4006 train_acc: 0.8596 val_loss: 0.6986 val_acc: 0.7669
# epoch(110) train_loss: 0.3933 train_acc: 0.8613 val_loss: 0.6985 val_acc: 0.771
# epoch(111) train_loss: 0.3882 train_acc: 0.8642 val_loss: 0.6973 val_acc: 0.7678
# epoch(112) train_loss: 0.3927 train_acc: 0.8623 val_loss: 0.7019 val_acc: 0.7677
# epoch(113) train_loss: 0.3849 train_acc: 0.864 val_loss: 0.6976 val_acc: 0.7664
# epoch(114) train_loss: 0.3865 train_acc: 0.865 val_loss: 0.6988 val_acc: 0.7715
# epoch(115) train_loss: 0.3823 train_acc: 0.8657 val_loss: 0.6972 val_acc: 0.767
# epoch(116) train_loss: 0.3783 train_acc: 0.8666 val_loss: 0.7054 val_acc: 0.7662
# epoch(117) train_loss: 0.3758 train_acc: 0.8687 val_loss: 0.7025 val_acc: 0.7659
# epoch(118) train_loss: 0.3786 train_acc: 0.8662 val_loss: 0.7028 val_acc: 0.7665
# epoch(119) train_loss: 0.3718 train_acc: 0.8704 val_loss: 0.7119 val_acc: 0.7661
# epoch(120) train_loss: 0.3799 train_acc: 0.8682 val_loss: 0.6998 val_acc: 0.765
# CPU times: user 35min 24s, sys: 3min 12s, total: 38min 36s
# Wall time: 38min 42s

# %%
'''
8. 損失と精度をグラフにする
'''
import matplotlib.pyplot as plt
# %matplotlib inline

# 学習結果（損失）のグラフを描画
plt.plot(history['loss'],
         marker='.',
         label='loss (Training)')
plt.plot(history['test_loss'],
         marker='.',
         label='loss (Test)')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# 学習結果（精度）のグラフを描画
plt.plot(history['accuracy'],
         marker='.',
         label='accuracy (Training)')
plt.plot(history['test_accuracy'],
         marker='.',
         label='accuracy (Test)')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()
